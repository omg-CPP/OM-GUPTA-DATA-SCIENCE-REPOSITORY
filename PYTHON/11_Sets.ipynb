# %% [markdown]
# Sets In Python

# %% [markdown]
# A set in Python is an unordered, mutable, and unique collection of elements. It
# does not allow duplicate values.

# %%
empty_set = set() # empty set

# %%
empty_set
# Out:
# set()

# %%
# Set with elements
numbers = {1, 2, 3, 4, 5}

# %%
numbers
# Out:
# {1, 2, 3, 4, 5}

# %%
# Mixed data types
mixed_set = {1, "Hello", 3.14, True}

# %%
mixed_set # 1 and True are considered as same so True evicted
# Out:
# {1, 3.14, 'Hello'}

# %%
# Creating a set from a list
unique_numbers = set([1, 2, 2, 3, 4, 4, 5])
print(unique_numbers)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# Common Set Methods

# %%
a = {}

# %%
type(a)
# Out:
# dict

# %%
b = set()

# %%
type(b)
# Out:
# set

# %%
s = {4,3,6,2,66,4}

# %%
s
# Out:
# {2, 3, 4, 6, 66}

# %%
s.add(34) # Adds an element

# %%
s
# Out:
# {2, 3, 4, 6, 34, 66}

# %%
s.update([43,24,66]) # Adds multiple elements

# %%
s
# Out:
# {2, 3, 4, 6, 24, 34, 43, 66}

# %%
s.remove(3)

# %%
s
# Out:
# {2, 4, 6, 24, 34, 43, 66}

# %%
s.discard(3) # don't give error even if element is not present in set

# %%
s
# Out:
# {2, 4, 6, 24, 34, 43, 66}

# %%
s.pop()
# Out:
# 2

# %%
s
# Out:
# {4, 6, 24, 34, 43, 66}

# %%
s.pop()
# Out:
# 4

# %%
s
# Out:
# {6, 24, 34, 43, 66}

# %%
newS = s.copy()

# %%
newS
# Out:
# {6, 24, 34, 43, 66}

# %%
s
# Out:
# {6, 24, 34, 43, 66}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1 # unchanged
# Out:
# {1, 2, 3, 4}

# %%
set2 # unchanged
# Out:
# {3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {3, 4}

# %%
set1 # unchanged
# Out:
# {1, 2, 3, 4}

# %%
set2 # unchanged
# Out:
# {3, 4, 5, 6}

# %%
print(set1 | set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
print(set1 & set2)
# Out:
# {3, 4}

# %%
# Difference – in set1 but not in set2
print(set1 - set2)
# {1, 2}
print(set1.difference(set2)) # same result
# Out:
# {1, 2}
# {1, 2}

# %%
# Symmetric Difference – in either set, but not both
print(set1 ^ set2)
# {1, 2, 5, 6}
print(set1.symmetric_difference(set2))# same result
# Out:
# {1, 2, 5, 6}
# {1, 2, 5, 6}

# %%
sub = {1, 3}

# %%
sub.issubset(set1)
# Out:
# True

# %%
sub.issubset(set2)
# Out:
# False

# %%
set1.issuperset(sub)
# Out:
# True

# %%
set2.issuperset(sub)
# Out:
# False

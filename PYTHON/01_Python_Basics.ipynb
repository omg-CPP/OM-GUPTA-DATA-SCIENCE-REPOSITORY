# %%
a = 5

# %%
b = 32

# %%
a + b
# Out:
# 37

# %%
name = "harry"

# %%
myName = "Atul"
print(name)
print(myName)
# Out:
# harry
# Atul

# %%
# This is a comment

# %%
print(type(a))
print(type(name))
# Out:
# <class 'int'>
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
a = "4566"
b = "5677"
print(a+b)
# Out:
# 45665677

# %%
print(int(a) + int(b)) # Typecasting
# Out:
# 10243

# %%
result = 10 + 2 * 3

# %%
result
# Out:
# 16

# %%
result = (10 + 2) * 3

# %%
result
# Out:
# 36

# %%
result = 2 ** 3 ** 2 # right to left exponentiation

# %%
result
# Out:
# 512

# %%
54 * 3 / 23 + 4 - 2
# Out:
# 9.043478260869566

# %%
54 * 3 / 23 + 4 - 2 ** 5 
# first exponentiation
# 54 * 3 / 23 + 4 - 32
# 162 / 23 + 4 - 32     ->  rest all operators like /,*,%,//,etc follow left to right
# 7.04 + 4 - 32
# 11.04 - 32
# -20.96
# Out:
# -20.956521739130434

# %%
11.04 - 32
# Out:
# -20.96

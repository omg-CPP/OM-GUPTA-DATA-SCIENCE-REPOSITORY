# %% [markdown]
# Taking Input from User

# %%
a = input("Enter the value of a : ") # by default it takes user input as a string
# Out:
# Enter the value of a :  45

# %%
print(a)
# Out:
# 45

# %%
b = input("Enter the value of b : ") # by default it takes user input as a string
# Out:
# Enter the value of b :  4

# %%
print(b)
# Out:
# 4

# %%
a + b
# Out:
# '454'

# %%
a
# Out:
# '45'

# %%
b
# Out:
# '4'

# %%
a + b # concatenation
# Out:
# '454'

# %%
int(a) + int(b) # integer typecasting
# Out:
# 49

# %%
c = input()
# Out:
#  2

# %%
c
# Out:
# '2'

# %%
age = int(input("Enter your age : "))
# Out:
# Enter your age :  4

# %%
print(age)
# Out:
# 4

# %%
age
# Out:
# 4

# %%
my_age = int(input("Enter your age:"))
# Out:
# Enter your age: 23

# %%
print(my_age)
# Out:
# 23

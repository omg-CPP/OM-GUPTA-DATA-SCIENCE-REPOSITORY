# %%
l = [3, 5, 23, 3]

# %%
l[0]
# Out:
# 3

# %%
l[1]
# Out:
# 5

# %%
l[2]
# Out:
# 23

# %%
l[3]
# Out:
# 3

# %%
l[0] = 45 # list is mutable

# %%
for item in l:
    print(item)
# Out:
# 45
# 5
# 23
# 3

# %%
l.append(9)

# %%
l
# Out:
# [45, 5, 23, 3, 9]

# %%
print(l)
# Out:
# [45, 5, 23, 3, 9]

# %%
l2 = [5, 7]

# %%
l.extend(l2)

# %%
l
# Out:
# [45, 5, 23, 3, 9, 5, 7]

# %%
l.insert(1,200) # insert 200 at index 1

# %%
l
# Out:
# [45, 200, 5, 23, 3, 9, 5, 7]

# %%
l.pop(4) # pops element at index 4
# Out:
# 3

# %%
l
# Out:
# [45, 200, 5, 23, 9, 5, 7]

# %%
l.index(45)
# Out:
# 0

# %%
l.remove(5) # removes the first occurence of 5 in list

# %%
l
# Out:
# [45, 200, 23, 9, 5, 7]

# %%
l.count(200)
# Out:
# 1

# %%
l.sort() # changes and sorts the original list

# %%
l
# Out:
# [5, 7, 9, 23, 45, 200]

# %%
l.reverse()

# %%
l
# Out:
# [200, 45, 23, 9, 7, 5]

# %% [markdown]
# sorted(list)

# %%
newList = [23,4,5,8,9]

# %%
sorted(newList) # returns a new list which is sorted
# Out:
# [4, 5, 8, 9, 23]

# %%
newList # original list remains the same
# Out:
# [23, 4, 5, 8, 9]

# %% [markdown]
# copy method

# %%
myList = [1,2,3,4]

# %%
myNewList = myList.copy() # returns a shallow copy of the list

# %%
myNewList
# Out:
# [1, 2, 3, 4]

# %%
myList
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# clear()

# %%
L = [1,2,3,4,5]

# %%
L.clear() # removes all elements from the list

# %%
L
# Out:
# []

# %% [markdown]
# Nested List

# %%
y = [1, 2, 3, True, False, "apple", [4, 5, 6], "banana", 7]

# %%
y
# Out:
# [1, 2, 3, True, False, 'apple', [4, 5, 6], 'banana', 7]

# %%
y[6]
# Out:
# [4, 5, 6]

# %%
y[6][0]
# Out:
# 4

# %% [markdown]
# list concatenation

# %%
list1 = [4, 32, 12]

# %%
list2 = [3, 1, 8]

# %%
list1 + list2
# Out:
# [4, 32, 12, 3, 1, 8]

# %%
list1
# Out:
# [4, 32, 12]

# %%
list2
# Out:
# [3, 1, 8]

# %%
# membership
if 3 in list2:
    print("Yes")
# Out:
# Yes

# %%
3 in list2
# Out:
# True

# %%
s = "akshay-kumar-salman-khan-ajay-devgan"

# %%
s
# Out:
# 'akshay-kumar-salman-khan-ajay-devgan'

# %%
s.split("-") # splitting a string to a list
# Out:
# ['akshay', 'kumar', 'salman', 'khan', 'ajay', 'devgan']

# %%
myList = [] # empty list

# %%
myList
# Out:
# []

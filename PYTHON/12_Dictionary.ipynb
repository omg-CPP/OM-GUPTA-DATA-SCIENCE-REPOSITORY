# %% [markdown]
# A dictionary in Python is an unordered, mutable, and key-value pair collection. It
# allows efficient data retrieval and modification. Dictionaries in Python are ordered
# as of Python 3.7

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
# Dictionary with key-value pairs
student = {
"name": "Alice",
"age": 25,
"grade": "A"
}

# %%
student
# Out:
# {'name': 'Alice', 'age': 25, 'grade': 'A'}

# %%
student["name"]
# Out:
# 'Alice'

# %%
student["age"]
# Out:
# 25

# %%
student["grade"]
# Out:
# 'A'

# %%
r = student.get("name")

# %%
print(r)
# Out:
# Alice

# %%
p = student.get("name4")

# %%
print(p)
# Out:
# None

# %% [markdown]
# mutable

# %%
student = {"name": "Alice", "age": 25, "grade": "A"}

# %%
# Adding a new key-value pair
student["city"] = "New York"

# %%
student
# Out:
# {'name': 'Alice', 'age': 25, 'grade': 'A', 'city': 'New York'}

# %%
print(student)
# Out:
# {'name': 'Alice', 'age': 25, 'grade': 'A', 'city': 'New York'}

# %%
# Updating an existing value
student["age"] = 26

# %%
student
# Out:
# {'name': 'Alice', 'age': 26, 'grade': 'A', 'city': 'New York'}

# %%
# Removing an item
student.pop("grade")
# Out:
# 'A'

# %%
student
# Out:
# {'name': 'Alice', 'age': 26, 'city': 'New York'}

# %%
# Iterating over a dictionary
for key, value in student.items():
    print(key, ":", value)
# Out:
# name : Alice
# age : 26
# city : New York

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
student.values()
# Out:
# dict_values(['Alice', 26, 'New York'])

# %%
student.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 26), ('city', 'New York')])

# %%
student.update({"name" : "Ruchika"}) # updates the dictionary

# %%
student
# Out:
# {'name': 'Ruchika', 'age': 26, 'city': 'New York'}

# %%
student.update({"name" : "Harry", "language" : "Python"})

# %%
student
# Out:
# {'name': 'Harry', 'age': 26, 'city': 'New York', 'language': 'Python'}

# %%
student.get("age",0) # returns key-value pair
# Out:
# 26

# %%
student.get("city",0)
# Out:
# 'New York'

# %%
student.get("grade",0) # key not defined
# Out:
# 0

# %%
student.pop("city")
# Out:
# 'New York'

# %%
student
# Out:
# {'name': 'Harry', 'age': 26, 'language': 'Python'}

# %%
student.popitem() # removes the last inserted key-value pair
# Out:
# ('language', 'Python')

# %%
student
# Out:
# {'name': 'Harry', 'age': 26}

# %%
new_Dict = student.copy()

# %%
new_Dict
# Out:
# {'name': 'Harry', 'age': 26}

# %%
student.clear()

# %%
student
# Out:
# {}

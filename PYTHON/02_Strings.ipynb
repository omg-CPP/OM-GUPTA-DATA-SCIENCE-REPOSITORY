# %%
name = "harry"
name
# Out:
# 'harry'

# %%
print(name)
# Out:
# harry

# %%
name.upper
# Out:
# <function str.upper()>

# %%
name.upper()
# Out:
# 'HARRY'

# %%
name.endswith("ry")
# Out:
# True

# %%
name
# Out:
# 'harry'

# %%
name.endswith("jerry")
# Out:
# False

# %%
name.lower()
# Out:
# 'harry'

# %%
name.count("a")
# Out:
# 1

# %%
name.count("r")
# Out:
# 2

# %%
s = "CodeWithHarry"
print(len(s))
# Out:
# 13

# %%
s = " Hello  "  # Removes leading and trailing spaces
print(s.strip())
# Out:
# Hello

# %%
s = "Hello World" # replace a substring with another
print(s.replace("World", "Python"))
# Out:
# Hello Python

# %%
s = "apple,banana,grape" # splits a string into a list based on a delimeter
print(s.split(","))
# Out:
# ['apple', 'banana', 'grape']

# %%
s = "CodeWithHarry" # brings the string from 0 to n-1 index, string slicing
s[0:5]
# Out:
# 'CodeW'

# %%
s[1:-1] # -1 is last index -> y
# Out:
# 'odeWithHarr'

# %%
s[1:12]
# Out:
# 'odeWithHarr'

# %%
s[-12:-1] # add len of string to both ends to resolve -ve indices
# Out:
# 'odeWithHarr'

# %%
s[1:12]
# Out:
# 'odeWithHarr'

# %%
s[2]
# Out:
# 'd'

# %%
s[:4]
# Out:
# 'Code'

# %%
x = 11
y = 5

# %%
x + y
# Out:
# 16

# %%
x - y
# Out:
# 6

# %%
x * y
# Out:
# 55

# %%
x / y # floating point number
# Out:
# 2.2

# %%
x // y # int number
# Out:
# 2

# %%
2 ** 5 # 2^5
# Out:
# 32

# %%
x % y # modulus operator
# Out:
# 1

# %%
a = 45
b = 4

# %%
a > b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# False

# %%
c = 4

# %%
a == c # is a equals to c ?
# Out:
# False

# %%
b == c
# Out:
# True

# %%
a != c
# Out:
# True

# %%
b1 = True
b2 = False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %%
a = 45
a += 4
a
# Out:
# 49

# %%
list = [1,2,3]
x = 2

# %%
x in list
# Out:
# True

# %%
x not in list
# Out:
# False

# %%
p = 5
q = 4

# %%
p is q
# Out:
# False

# %%
p is not q
# Out:
# True

# %%
e = ()

# %%
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
l = []

# %%
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
t = (5,6,23,4)

# %%
t
# Out:
# (5, 6, 23, 4)

# %%
len(t)
# Out:
# 4

# %%
t[1]
# Out:
# 6

# %%
t[2]
# Out:
# 23

# %%
# Tuples are immutable i.e. cannot be changed

# %%
mixed_tuple = (1, "Hello", 3.14, True)

# %%
mixed_tuple
# Out:
# (1, 'Hello', 3.14, True)

# %%
single_element = (42,)

# %%
single_element
# Out:
# (42,)

# %%
# Packing
person = ("Alice", 25, "Engineer")
# Unpacking
name, age, profession = person

# %%
name
# Out:
# 'Alice'

# %%
age
# Out:
# 25

# %%
profession
# Out:
# 'Engineer'

# %%
my_tuple = (10, 20, 30, 40)
# Indexing
print(my_tuple[1]) # 20
# Slicing
print(my_tuple[1:3]) # (20, 30)
# Out:
# 20
# (20, 30)

# %%
t = (3,4,5,6,3)

# %%
t.count(3)
# Out:
# 2

# %%
t.index(3) # returns the index of the first occurence of 3
# Out:
# 0

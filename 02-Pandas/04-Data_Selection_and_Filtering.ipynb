# %% [markdown]
# ## Data Selection & Filtering

# %%
import pandas as pd

# %%
df = pd.read_csv("data2.csv")

# %%
df
# Out:
#       Actor       Film   Year      Genre  Box Office  IMDB
# 0       SRK      Pathan  2001     Action        1050   7.2
# 1    Salman       Tiger  2002     Action         456   9.8
# 2     Aamir      Dangal  2003  Biography         120   5.6
# 3    Akshay   Good News  2004     Comedy         100   5.6
# 4      Ajay     Singham  2005     Action         480   4.6
# 5     Varun        HSKD  2006     Action         456   7.8
# 6  Siddhant  Gehraiyaan  2007   Thriller         145   8.6
# 7     Vicky    Shiva Ji  2008     Action         254   3.2
# 8    Ranbir        YJHD  2009    Rom-Com         154   5.6
# 9   Ranveer   Dhurandar  2010     Action        1700  10.0

# %%
# selecting colmn
df['Actor']
# Out:
# 0         SRK
# 1      Salman
# 2       Aamir
# 3      Akshay
# 4        Ajay
# 5       Varun
# 6    Siddhant
# 7       Vicky
# 8      Ranbir
# 9     Ranveer
# Name: Actor, dtype: object

# %%
df['Actor'][3]
# Out:
# 'Akshay'

# %%
type(df['Actor'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Actor','IMDB']]
# Out:
#       Actor  IMDB
# 0       SRK   7.2
# 1    Salman   9.8
# 2     Aamir   5.6
# 3    Akshay   5.6
# 4      Ajay   4.6
# 5     Varun   7.8
# 6  Siddhant   8.6
# 7     Vicky   3.2
# 8    Ranbir   5.6
# 9   Ranveer  10.0

# %%
df
# Out:
#       Actor       Film   Year      Genre  Box Office  IMDB
# 0       SRK      Pathan  2001     Action        1050   7.2
# 1    Salman       Tiger  2002     Action         456   9.8
# 2     Aamir      Dangal  2003  Biography         120   5.6
# 3    Akshay   Good News  2004     Comedy         100   5.6
# 4      Ajay     Singham  2005     Action         480   4.6
# 5     Varun        HSKD  2006     Action         456   7.8
# 6  Siddhant  Gehraiyaan  2007   Thriller         145   8.6
# 7     Vicky    Shiva Ji  2008     Action         254   3.2
# 8    Ranbir        YJHD  2009    Rom-Com         154   5.6
# 9   Ranveer   Dhurandar  2010     Action        1700  10.0

# %%
# selecting rows
df.loc[1] # by label if changed to 'A'
# Out:
# Actor         Salman
# Film           Tiger
# Year            2002
# Genre         Action
# Box Office       456
# IMDB             9.8
# Name: 1, dtype: object

# %%
df.iloc[1] # by position (index)
# Out:
# Actor         Salman
# Film           Tiger
# Year            2002
# Genre         Action
# Box Office       456
# IMDB             9.8
# Name: 1, dtype: object

# %%
# select specific rows and columns
df.loc[8, 'IMDB']
# Out:
# np.float64(5.6)

# %%
df.iloc[8, 5]
# Out:
# np.float64(5.6)

# %%
df.loc[0:2, ['Actor', 'IMDB']] # inclusive
# Out:
#     Actor  IMDB
# 0     SRK   7.2
# 1  Salman   9.8
# 2   Aamir   5.6

# %%
df.iloc[0:2, 0:2] # exclusive
# Out:
#     Actor   Film
# 0     SRK  Pathan
# 1  Salman   Tiger

# %%
df.at[0, 'Actor'] # for single element
# Out:
# 'SRK'

# %%
df.iat[0, 0]
# Out:
# 'SRK'

# %% [markdown]
# - filtering

# %%
df[df['IMDB'] > 6]
# Out:
#       Actor       Film   Year     Genre  Box Office  IMDB
# 0       SRK      Pathan  2001    Action        1050   7.2
# 1    Salman       Tiger  2002    Action         456   9.8
# 5     Varun        HSKD  2006    Action         456   7.8
# 6  Siddhant  Gehraiyaan  2007  Thriller         145   8.6
# 9   Ranveer   Dhurandar  2010    Action        1700  10.0

# %%
df[df['IMDB'] > 6]['Actor']
# Out:
# 0         SRK
# 1      Salman
# 5       Varun
# 6    Siddhant
# 9     Ranveer
# Name: Actor, dtype: object

# %%
df.columns
df.columns = df.columns.str.strip()  # remove spaces

# %%
df[(df['IMDB'] > 5) & (df['Year'] > 2003)]
# Out:
#       Actor        Film  Year     Genre  Box Office  IMDB
# 3    Akshay   Good News  2004    Comedy         100   5.6
# 5     Varun        HSKD  2006    Action         456   7.8
# 6  Siddhant  Gehraiyaan  2007  Thriller         145   8.6
# 8    Ranbir        YJHD  2009   Rom-Com         154   5.6
# 9   Ranveer   Dhurandar  2010    Action        1700  10.0

# %%
df.query("Year > 2001 and IMDB > 6")
# Out:
#       Actor        Film  Year     Genre  Box Office  IMDB
# 1    Salman       Tiger  2002    Action         456   9.8
# 5     Varun        HSKD  2006    Action         456   7.8
# 6  Siddhant  Gehraiyaan  2007  Thriller         145   8.6
# 9   Ranveer   Dhurandar  2010    Action        1700  10.0

# %%
df.query("Actor == 'Akshay' and Genre == 'Comedy'")
# Out:
#     Actor       Film  Year   Genre  Box Office  IMDB
# 3  Akshay  Good News  2004  Comedy         100   5.6

# %%
# If a column name has spaces, use backticks (`)
# df.query("`first name` == 'Alice'")

# %%
# You can use @ to reference Python variables
rating = 5
df.query("IMDB > @rating")
# Out:
#       Actor        Film  Year      Genre  Box Office  IMDB
# 0       SRK      Pathan  2001     Action        1050   7.2
# 1    Salman       Tiger  2002     Action         456   9.8
# 2     Aamir      Dangal  2003  Biography         120   5.6
# 3    Akshay   Good News  2004     Comedy         100   5.6
# 5     Varun        HSKD  2006     Action         456   7.8
# 6  Siddhant  Gehraiyaan  2007   Thriller         145   8.6
# 8    Ranbir        YJHD  2009    Rom-Com         154   5.6
# 9   Ranveer   Dhurandar  2010     Action        1700  10.0

# %%
df2 = df[['Actor', 'IMDB']].copy()

# %%
df2
# Out:
#       Actor  IMDB
# 0       SRK   7.2
# 1    Salman   9.8
# 2     Aamir   5.6
# 3    Akshay   5.6
# 4      Ajay   4.6
# 5     Varun   7.8
# 6  Siddhant   8.6
# 7     Vicky   3.2
# 8    Ranbir   5.6
# 9   Ranveer  10.0

# %%
df2.loc[0, 'Actor'] = 'Harry' # changes are not made to df

# %%
df2
# Out:
#       Actor  IMDB
# 0     Harry   7.2
# 1    Salman   9.8
# 2     Aamir   5.6
# 3    Akshay   5.6
# 4      Ajay   4.6
# 5     Varun   7.8
# 6  Siddhant   8.6
# 7     Vicky   3.2
# 8    Ranbir   5.6
# 9   Ranveer  10.0

# %%
df
# Out:
#       Actor        Film  Year      Genre  Box Office  IMDB
# 0       SRK      Pathan  2001     Action        1050   7.2
# 1    Salman       Tiger  2002     Action         456   9.8
# 2     Aamir      Dangal  2003  Biography         120   5.6
# 3    Akshay   Good News  2004     Comedy         100   5.6
# 4      Ajay     Singham  2005     Action         480   4.6
# 5     Varun        HSKD  2006     Action         456   7.8
# 6  Siddhant  Gehraiyaan  2007   Thriller         145   8.6
# 7     Vicky    Shiva Ji  2008     Action         254   3.2
# 8    Ranbir        YJHD  2009    Rom-Com         154   5.6
# 9   Ranveer   Dhurandar  2010     Action        1700  10.0

# %%
# .query() returns a copy, not a view

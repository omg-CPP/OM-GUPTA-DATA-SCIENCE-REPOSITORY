# %% [markdown]
# ## Getting Started with Pandas

# %%
import pandas as pd

# %% [markdown]
# - Pandas - Pandas bridges the gap between NumPy performance and Excel-like usability
# - Pandas is built on top of NumPy
# - Use Pandas when working with structured data

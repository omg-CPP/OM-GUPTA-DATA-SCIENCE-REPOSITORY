# %%
import pandas as pd

# %% [markdown]
# - Series → One-dimensional (like a single column in Excel)
# - DataFrame → Two-dimensional (like a full spreadsheet or SQL table)

# %%
s = pd.Series([1,4,56,23,56,98,56])

# %%
s
# Out:
# 0     1
# 1     4
# 2    56
# 3    23
# 4    56
# 5    98
# 6    56
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
print(s)
# Out:
# 0     1
# 1     4
# 2    56
# 3    23
# 4    56
# 5    98
# 6    56
# dtype: int64

# %%
# custom index
s1 = pd.Series([1,4,56,23,56,98,56], index=["A","B","C","D","E","F","G"])

# %%
print(s1)
# Out:
# A     1
# B     4
# C    56
# D    23
# E    56
# F    98
# G    56
# dtype: int64

# %%
s1["A"]
# Out:
# np.int64(1)

# %% [markdown]
# - A pandas.Series may look similar to a Python dictionary because both store data
# with labels, but a Series offers much more. Unlike a dictionary, a Series supports
# fast vectorized operations.
# - It also allows both label-based and position
# based access, and integrates seamlessly with the pandas ecosystem, especially
# DataFrames.
# - While a dictionary is great for simple key–value storage, a Series is
# better suited for data analysis and manipulation tasks where performance,
# flexibility, and built-in functionality matter.

# %% [markdown]
# ### Dataframe

# %% [markdown]
# - A
# DataFrame is like a dictionary of Series — multiple columns with labels.

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

# %%
data
# Out:
# {'name': ['Alice', 'Bob', 'Charlie'],
#  'age': [25, 30, 35],
#  'city': ['Delhi', 'Mumbai', 'Bangalore']}

# %%
# tabular data ko python me store kara efficiently
df = pd.DataFrame(data)
print(df)
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
# Each column in a DataFrame is a Series .
df
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.index # row labels
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns # column labels
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
df.index = ["a", "b", "c"]
df.columns = ["Name", "Age", "City"]

# %%
df
# Out:
#       Name  Age       City
# a    Alice   25      Delhi
# b      Bob   30     Mumbai
# c  Charlie   35  Bangalore

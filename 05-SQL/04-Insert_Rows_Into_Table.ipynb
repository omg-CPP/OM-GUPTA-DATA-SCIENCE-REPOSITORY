# %% [markdown]
# ## How to Insert Rows into a Table in MySQL

# %% [markdown]
# - refer to sql_file_1.sql

# %% [markdown]
# ## How to Select Data in MySQL

# %% [markdown]
# - refer to sql_file_2.sql

# %% [markdown]
# #### 1. Basic
# - SELECT Statement
# - To retrieve all data from the student table:
#   - SELECT * FROM student;
# - To retrieve specific columns (e.g., only name and grade):
#   - SELECT name, grade FROM student;

# %% [markdown]
# #### Handling NULL Values
# - What is NULL ?
#   - NULL represents missing or unknown values. It is not equal to any other value.

# %% [markdown]
# #### Combining Conditions
# - You can use AND , OR , and parentheses to combine conditions.

# %% [markdown]
# #### Sorting Results with ORDER BY

# %% [markdown]
# #### Limiting Results with LIMIT
